# %%
import sys
sys.path.append("../")

# %%
import utils

# %%
import data

# %%
dms = data.midi_data_module.MidiDataModule(data_dir="~/midi_features",
                                          batch_size=1000)

# %%
dms.setup()
# Out:
# Generating input tensors on cuda
# Generating tensors
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 140944/140944 [00:21<00:00, 6612.36it/s]

# %%
x = np.load("/home/joy/midi_fid_eval/Lyricspage.mid.npy")

# %%
import numpy as np

# %%
x
# Out:
# array([[-0.25782722, -0.20568492, -0.46211717, -0.46211717, -0.4572681 ,
#         -0.45677257],
#        [-0.23192267, -0.20568492, -0.46211717, -0.46211717, -0.4572681 ,
#         -0.45675233],
#        [-0.24306734, -0.19434653, -0.46211717, -0.46211717, -0.4572681 ,
#         -0.45674226],
#        ...,
#        [-0.3367247 , -0.34715453, -0.4496424 , -0.35749924, -0.39972195,
#         -0.39938888],
#        [-0.34368727, -0.29419228, -0.4496424 , -0.35749924, -0.39970046,
#         -0.3991095 ],
#        [-0.34368727, -0.2905919 , -0.4496424 , -0.35749924, -0.3984108 ,
#         -0.39780846]], dtype=float32)

# %%
x.shape
# Out:
# (585, 6)

# %%
x = x.reshape((585//5, 30))

# %%
x.shape
# Out:
# (117, 30)

# %%
x = x.reshape((117//3, 90))

# %%
x.shape
# Out:
# (39, 90)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x)
