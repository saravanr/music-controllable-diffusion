# %%
import os
import numpy as np
import torch

# %%
import sys
sys.path.append("../")
from models.simple_vae import simple_vae

# %%
import os
import numpy as np
import mido
import sys
import tqdm
from utils.file_utils import get_files_in_path
MODEL_PATH = os.path.expanduser("~/projects/music-controllable-diffusion/models/simple_vae/simplevae.chkpoint.720000")

# %%
z_dim = 200
input_shape = (245, 286)
model = simple_vae.SimpleVae.load_from_checkpoint(MODEL_PATH, z_dim=z_dim, input_shape=input_shape)

# %%
model
# Out:
# SimpleVae(
#   (_encoder): Encoder(
#     (_net): Sequential(
#       (0): Linear(in_features=70070, out_features=3503, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): Linear(in_features=3503, out_features=3503, bias=True)
#       (3): LeakyReLU(negative_slope=0.01)
#       (4): Linear(in_features=3503, out_features=1751, bias=True)
#       (5): LeakyReLU(negative_slope=0.01)
#       (6): Linear(in_features=1751, out_features=875, bias=True)
#     )
#     (_fc_mean): Linear(in_features=875, out_features=200, bias=True)
#     (_fc_var): Linear(in_features=875, out_features=200, bias=True)
#   )
#   (_decoder): Decoder(
#     (_net): Sequential(
#       (0): Linear(in_features=200, out_features=1751, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): Linear(in_features=1751, out_features=3503, bias=True)
#       (3): LeakyReLU(negative_slope=0.01)
#       (4): Linear(in_features=3503, out_features=3503, bias=True)
#       (5): LeakyReLU(negative_slope=0.01)
#       (6): Linear(in_features=3503, out_features=70070, bias=True)
#     )
#   )
# )

# %%
input_rand_tensor = torch.rand((z_dim))
generated_midi_npy = model._decoder(input_rand_tensor).detach().numpy()

# %%
generated_midi_npy = generated_midi_npy[0]

# %%
generated_midi_npy.shape
# Out:
# (245, 286)

# %%
from utils.midi_utils import MidiConverter, play_note_seq

# %%
notes = MidiConverter.to_note_seq(generated_midi_npy)

# %%
play_note_seq(notes)
# Out:
# fluidsynth: warning: SDL2 not initialized, SDL2 audio driver won't be usable
# fluidsynth: error: There is no preset with bank number 0 and preset number 146 in SoundFont 1
# fluidsynth: warning: SDL2 not initialized, SDL2 audio driver won't be usable
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_746745/4241547015.py in <module>
# ----> 1 play_note_seq(notes)
#
# ~/projects/music-controllable-diffusion/notebooks/../utils/midi_utils.py in play_note_seq(note_sequence_object)
#      22     :return:
#      23     """
# ---> 24     play_sequence(note_sequence_object, synth=note_seq.fluidsynth)
#      25
#      26
#
# ~/.venv/lib/python3.8/site-packages/note_seq/notebook_utils.py in play_sequence(sequence, synth, sample_rate, colab_ephemeral, **synth_args)
#      96     **synth_args: Additional keyword arguments to pass to the synth function.
#      97   """
# ---> 98   array_of_floats = synth(sequence, sample_rate=sample_rate, **synth_args)
#      99
#     100   try:
#
# ~/.venv/lib/python3.8/site-packages/note_seq/midi_synth.py in fluidsynth(sequence, sample_rate, sf2_path)
#      53   """
#      54   midi = midi_io.note_sequence_to_pretty_midi(sequence)
# ---> 55   return midi.fluidsynth(fs=sample_rate, sf2_path=sf2_path)
#
# ~/.venv/lib/python3.8/site-packages/pretty_midi/pretty_midi.py in fluidsynth(self, fs, sf2_path)
#     943             return np.array([])
#     944         # Get synthesized waveform for each instrument
# --> 945         waveforms = [i.fluidsynth(fs=fs,
#     946                                   sf2_path=sf2_path) for i in self.instruments]
#     947         # Allocate output waveform, with #sample = max length of all waveforms
#
# ~/.venv/lib/python3.8/site-packages/pretty_midi/pretty_midi.py in <listcomp>(.0)
#     943             return np.array([])
#     944         # Get synthesized waveform for each instrument
# --> 945         waveforms = [i.fluidsynth(fs=fs,
#     946                                   sf2_path=sf2_path) for i in self.instruments]
#     947         # Allocate output waveform, with #sample = max length of all waveforms
#
# ~/.venv/lib/python3.8/site-packages/pretty_midi/instrument.py in fluidsynth(self, fs, sf2_path)
#     522             end = int(fs*(current_time + event[0]))
#     523             samples = fl.get_samples(end - current_sample)[::2]
# --> 524             synthesized[current_sample:end] += samples
#     525             # Increment the current sample
#     526             current_time += event[0]
#
# ValueError: operands could not be broadcast together with shapes (0,) (90674,) (0,)

# %%
notes
# Out:
# notes {
#   pitch: -7
#   velocity: -19
#   start_time: 1.0061571598052979
#   end_time: -0.027542784810066223
#   instrument: 155
#   program: 172
# }
# notes {
#   pitch: 130
#   velocity: -12
#   start_time: 0.14745348691940308
#   end_time: 0.2608863115310669
#   instrument: 47
#   program: 193
# }
# notes {
#   pitch: -13
#   velocity: 236
#   start_time: 1.0938746929168701
#   end_time: 1.4624980688095093
#   instrument: 23
#   program: 104
# }
# notes {
#   pitch: 40
#   velocity: -157
#   start_time: -0.5121347904205322
#   end_time: 2.0557022094726562
#   instrument: 176
#   program: 129
# }
# notes {
#   pitch: 188
#   velocity: 113
#   start_time: -0.4245791435241699
#   end_time: -0.44148990511894226
#   instrument: 11
#   program: -61
# }
# notes {
#   pitch: 199
#   velocity: 50
#   start_time: 1.4382951259613037
#   end_time: 1.2274677753448486
#   instrument: 146
#   program: 68
# }
# notes {
#   pitch: 2616
#   velocity: 40
#   start_time: -0.32305091619491577
#   end_time: 1.3650742769241333
#   instrument: -6
#   program: 117
# }
# notes {
#   pitch: 221
#   velocity: 61
#   start_time: 0.05200231075286865
#   end_time: -0.9621453881263733
#   instrument: 182
#   program: 155
# }
# notes {
#   pitch: 96
#   velocity: 221
#   start_time: -0.6832247376441956
#   end_time: 0.7499294281005859
#   instrument: -146
#   program: -68
# }
# notes {
#   pitch: 43
#   velocity: 169
#   start_time: -0.03704798221588135
#   end_time: 1.3060402870178223
#   instrument: 142
#   program: -46
# }
# notes {
#   pitch: 45
#   velocity: -80
#   start_time: 0.9664424657821655
#   end_time: 1.4059463739395142
#   instrument: 181
#   program: 165
# }
# notes {
#   pitch: 142
#   velocity: 109
#   start_time: -0.20024102926254272
#   end_time: -0.07304158806800842
#   instrument: -111
#   program: 165
# }
# notes {
#   pitch: 150
#   velocity: 7
#   start_time: 1.5324989557266235
#   end_time: 0.3357886075973511
#   instrument: 174
#   program: -38
# }
# notes {
#   pitch: 78
#   velocity: 34
#   start_time: -0.37256771326065063
#   end_time: 1.7067824602127075
#   instrument: -16
#   program: -59
# }
# notes {
#   pitch: 134
#   velocity: 35
#   start_time: 0.15255135297775269
#   end_time: 0.31814077496528625
#   instrument: 179
#   program: -26
# }
# notes {
#   pitch: 253
#   velocity: 105
#   start_time: 1.5559051036834717
#   end_time: 0.8123649954795837
#   instrument: 40
#   program: 62
# }
# notes {
#   pitch: -148
#   velocity: 154
#   start_time: 0.8551647067070007
#   end_time: 1.6882621049880981
#   instrument: -7
#   program: 66
# }
# notes {
#   pitch: 99
#   velocity: -191
#   start_time: 0.5303618311882019
#   end_time: 0.41679462790489197
#   instrument: 100
#   program: 18
# }
# notes {
#   pitch: 14
#   velocity: -12
#   start_time: 0.9315486550331116
#   end_time: 0.4608159363269806
#   instrument: -18
#   program: 82
# }
# notes {
#   pitch: -7
#   velocity: 7
#   start_time: 1.529868483543396
#   end_time: 1.126791000366211
#   instrument: 98
#   program: -49
# }
# notes {
#   pitch: -24
#   velocity: 59
#   start_time: -0.1505439579486847
#   end_time: 0.7519424557685852
#   instrument: 158
#   program: 143
# }
# notes {
#   pitch: 188
#   velocity: -61
#   start_time: 0.8722463846206665
#   end_time: -0.902337372303009
#   instrument: 162
# }
# notes {
#   pitch: 48
#   velocity: 103
#   start_time: 1.6500582695007324
#   end_time: 1.220569372177124
#   instrument: 100
#   program: 49
# }
# notes {
#   pitch: 96
#   velocity: 115
#   start_time: 0.4102281332015991
#   end_time: 1.184531331062317
#   instrument: 12
#   program: -63
# }
# notes {
#   pitch: -5
#   velocity: 9
#   start_time: 1.026019811630249
#   end_time: 0.8238314390182495
#   instrument: 199
#   program: 166
# }
# notes {
#   pitch: 182
#   velocity: 76
#   start_time: -0.2405725121498108
#   end_time: 0.3845381736755371
#   instrument: 93
#   program: 226
# }
# notes {
#   pitch: 100
#   velocity: -108
#   start_time: 1.5895144939422607
#   end_time: 1.5020623207092285
#   instrument: 123
#   program: -9
# }
# notes {
#   pitch: -163
#   velocity: 27
#   start_time: -0.08537331223487854
#   end_time: 1.8140580654144287
#   instrument: -24
#   program: 20
# }
# notes {
#   pitch: -1
#   velocity: 133
#   start_time: -0.33767884969711304
#   end_time: 0.8940446972846985
#   instrument: 128
#   program: 200
# }
# notes {
#   pitch: 207
#   velocity: 3
#   start_time: 0.31749939918518066
#   end_time: 0.5543913841247559
#   instrument: -126
#   program: 173
# }
# notes {
#   pitch: -47
#   velocity: 143
#   start_time: 0.24794024229049683
#   end_time: -0.19388532638549805
#   instrument: 78
#   program: -150
# }
# notes {
#   pitch: 139
#   velocity: -1
#   start_time: -0.28192412853240967
#   end_time: 0.25038546323776245
#   instrument: -5
#   program: 177
# }
# notes {
#   pitch: 159
#   velocity: 105
#   start_time: -0.36564087867736816
#   end_time: 0.1667652726173401
#   instrument: 15
#   program: 189
# }
# notes {
#   pitch: 102
#   velocity: -1
#   start_time: 0.418052613735199
#   end_time: 1.7260010242462158
#   instrument: 38
#   program: 140
# }
# notes {
#   pitch: -50
#   velocity: 35
#   start_time: -0.40984994173049927
#   end_time: 1.8225245475769043
#   instrument: 140
#   program: 76
# }
# notes {
#   pitch: 189
#   velocity: -48
#   start_time: 0.9201138019561768
#   end_time: 0.23545809090137482
#   instrument: 147
#   program: 202
# }
# notes {
#   pitch: 186
#   velocity: 212
#   start_time: 1.0491278171539307
#   end_time: -0.21180185675621033
#   instrument: 143
#   program: 190
# }
# notes {
#   pitch: 141
#   velocity: 100
#   start_time: 0.9549270868301392
#   end_time: 1.4135172367095947
#   instrument: 182
#   program: 141
# }
# notes {
#   pitch: -42
#   velocity: 58
#   start_time: -1.108351469039917
#   end_time: 1.5738589763641357
#   instrument: 241
#   program: 161
# }
# notes {
#   pitch: 122
#   velocity: -42
#   start_time: 0.1229521632194519
#   end_time: -0.8339707255363464
#   instrument: -92
#   program: 63
# }
# notes {
#   pitch: 151
#   velocity: -14
#   start_time: 0.848393440246582
#   end_time: 0.9770740270614624
#   instrument: -26
#   program: -95
# }
# notes {
#   pitch: -84
#   velocity: 41
#   start_time: -0.4046499729156494
#   end_time: 1.0289695262908936
#   instrument: 104
#   program: -1
# }
# notes {
#   pitch: -24
#   velocity: -13
#   start_time: 0.9205466508865356
#   end_time: -0.025673121213912964
#   instrument: -32
#   program: 55
# }
# notes {
#   pitch: 73
#   velocity: 9
#   start_time: 1.1120452880859375
#   end_time: 0.06965351104736328
#   instrument: -113
#   program: 29
# }
# notes {
#   pitch: 42
#   velocity: 210
#   start_time: 0.11499530076980591
#   end_time: 1.742374300956726
#   instrument: 136
#   program: 53
# }
# notes {
#   pitch: -25
#   velocity: -126
#   start_time: 0.9833076000213623
#   end_time: 0.21518832445144653
#   instrument: 81
#   program: 169
# }
# notes {
#   pitch: 121
#   velocity: -4
#   start_time: 0.22022885084152222
#   end_time: 1.1211984157562256
#   instrument: -33
#   program: 115
# }
# notes {
#   pitch: 173
#   velocity: 76
#   start_time: 0.530854344367981
#   end_time: 1.8120927810668945
#   instrument: -76
#   program: 147
# }
# notes {
#   pitch: 76
#   velocity: 6
#   start_time: -0.2625456750392914
#   end_time: 0.42418426275253296
#   instrument: -22
#   program: 162
# }
# notes {
#   pitch: 33
#   velocity: 19
#   start_time: -0.06342124938964844
#   end_time: -0.46939539909362793
#   instrument: 11
#   program: 163
# }
# notes {
#   pitch: 54
#   velocity: 147
#   start_time: -0.24206411838531494
#   end_time: 0.7224400043487549
#   instrument: -55
#   program: 171
# }
# notes {
#   pitch: -11
#   velocity: 77
#   start_time: 1.4046825170516968
#   end_time: 0.2862989902496338
#   instrument: 150
#   program: 43
# }
# notes {
#   pitch: -21
#   velocity: -22
#   start_time: 0.32130926847457886
#   end_time: 1.5590388774871826
#   instrument: -11
#   program: 10
# }
# notes {
#   pitch: 138
#   velocity: 91
#   start_time: -0.2758539319038391
#   end_time: -0.7520429491996765
#   instrument: 52
#   program: 145
# }
# notes {
#   pitch: 126
#   velocity: 42
#   start_time: 1.1884591579437256
#   end_time: -0.12014639377593994
#   instrument: 140
#   program: 19
# }
# notes {
#   pitch: -135
#   velocity: 20
#   start_time: 0.18255195021629333
#   end_time: 1.848388910293579
#   instrument: 119
#   program: 134
# }
# notes {
#   pitch: 17
#   velocity: -35
#   start_time: 1.0507328510284424
#   end_time: 0.2595091462135315
#   instrument: -34
#   program: 132
# }
# notes {
#   pitch: 113
#   velocity: 37
#   start_time: 0.7026616930961609
#   end_time: -0.44039374589920044
#   instrument: 171
#   program: -39
# }
# notes {
#   pitch: -108
#   velocity: 136
#   start_time: 1.6025665998458862
#   end_time: -0.27627289295196533
#   instrument: -21
#   program: -101
# }
# notes {
#   pitch: 9
#   velocity: 93
#   start_time: -0.6499919891357422
#   end_time: 1.4104068279266357
#   instrument: 30
#   program: 168
# }
# notes {
#   pitch: -30
#   velocity: 156
#   start_time: 1.3696476221084595
#   end_time: 0.9444926977157593
#   instrument: 40
#   program: 174
# }
# notes {
#   pitch: 111
#   velocity: 21
#   start_time: 0.7899080514907837
#   end_time: 0.06310665607452393
#   instrument: -30
#   program: 63
# }
# notes {
#   pitch: 117
#   velocity: 49
#   start_time: -0.5343406200408936
#   end_time: 1.9793171882629395
#   instrument: -70
#   program: 133
# }
# notes {
#   pitch: 218
#   velocity: -56
#   start_time: 0.3226557672023773
#   end_time: 1.6412190198898315
#   instrument: 134
#   program: 145
# }
# notes {
#   pitch: 111
#   velocity: 92
#   start_time: 0.8095600605010986
#   end_time: 1.1783266067504883
#   instrument: -80
#   program: 159
# }
# notes {
#   pitch: -105
#   velocity: 192
#   start_time: 0.20381665229797363
#   end_time: 1.2521288394927979
#   instrument: 154
#   program: 18
# }
# notes {
#   pitch: -22
#   velocity: -37
#   start_time: -0.34200942516326904
#   end_time: 0.23445624113082886
#   instrument: -11
#   program: 180
# }
# notes {
#   pitch: 221
#   velocity: 157
#   start_time: 1.7674051523208618
#   end_time: 0.8539172410964966
#   instrument: 30
#   program: 103
# }
# notes {
#   pitch: 154
#   velocity: -30
#   start_time: 0.42715054750442505
#   end_time: 1.0306496620178223
#   instrument: -5
#   program: 86
# }
# notes {
#   pitch: 116
#   velocity: 49
#   start_time: -0.09310770034790039
#   end_time: 0.5780327320098877
#   instrument: 82
#   program: 172
# }
# notes {
#   pitch: 7
#   velocity: 126
#   start_time: -0.5952173471450806
#   end_time: 0.766072154045105
#   instrument: 16
#   program: 189
# }
# notes {
#   pitch: 80
#   velocity: 117
#   start_time: 0.05882352590560913
#   end_time: -0.7545984983444214
#   instrument: -184
#   program: 118
# }
# notes {
#   pitch: 82
#   velocity: 74
#   start_time: 1.4162771701812744
#   end_time: 0.5430984497070312
#   instrument: 159
#   program: -169
# }
# notes {
#   pitch: 123
#   velocity: -61
#   start_time: -0.7696296572685242
#   end_time: 1.7075597047805786
#   instrument: 6
#   program: 10
# }
# notes {
#   pitch: 119
#   velocity: 45
#   start_time: 0.9826887845993042
#   end_time: -0.7047752141952515
#   instrument: 28
#   program: 17
# }
# notes {
#   pitch: 149
#   velocity: 18
#   start_time: 0.27644944190979004
#   end_time: 0.11505234241485596
#   instrument: 145
#   program: 80
# }
# notes {
#   pitch: 20
#   velocity: 51
#   start_time: -0.5633490085601807
#   end_time: 0.36856210231781006
#   instrument: 161
#   program: 111
# }
# notes {
#   pitch: 141
#   velocity: 6
#   start_time: 0.8762030005455017
#   end_time: -0.7929849028587341
#   instrument: 192
#   program: -61
# }
# notes {
#   pitch: 217
#   velocity: 191
#   start_time: 1.0133886337280273
#   end_time: 0.6655692458152771
#   instrument: -32
#   program: -36
# }
# notes {
#   pitch: -2
#   velocity: 227
#   start_time: 1.0588133335113525
#   end_time: -0.25868529081344604
#   instrument: 83
#   program: -150
# }
# notes {
#   pitch: -26
#   velocity: 152
#   start_time: 0.4384881556034088
#   end_time: 1.7010806798934937
#   instrument: 188
#   program: 19
# }
# notes {
#   pitch: 138
#   velocity: -69
#   start_time: 0.9573187828063965
#   end_time: 0.864632248878479
#   instrument: -34
#   program: 148
# }
# notes {
#   pitch: 177
#   velocity: 35
#   start_time: 0.3465498089790344
#   end_time: -0.15189015865325928
#   instrument: -62
#   program: 96
# }
# notes {
#   pitch: 36
#   velocity: 37
#   start_time: -1.0126444101333618
#   end_time: 0.8561224341392517
#   instrument: 109
#   program: 132
# }
# notes {
#   pitch: 9
#   velocity: 3
#   start_time: 1.0109047889709473
#   end_time: -0.12484888732433319
#   instrument: -1
#   program: 10
# }
# notes {
#   pitch: 99
#   velocity: -37
#   start_time: 1.2746211290359497
#   end_time: 0.10658484697341919
#   instrument: 28
#   program: 172
# }
# notes {
#   pitch: -42
#   velocity: 71
#   start_time: 0.09955322742462158
#   end_time: 1.486253023147583
#   instrument: 179
#   program: -61
# }
# notes {
#   pitch: 82
#   velocity: 46
#   start_time: -0.13542820513248444
#   end_time: 0.027777016162872314
#   instrument: 111
#   program: -32
# }
# notes {
#   pitch: 176
#   velocity: -69
#   start_time: -0.368438720703125
#   end_time: -0.3265724182128906
#   instrument: -70
#   program: 55
# }
# notes {
#   pitch: 174
#   velocity: 37
#   start_time: 1.4839893579483032
#   end_time: 0.14836406707763672
#   instrument: -30
#   program: 67
# }
# notes {
#   pitch: -76
#   velocity: 74
#   start_time: 1.0972075462341309
#   end_time: 2.0724616050720215
#   instrument: 198
#   program: -91
# }
# notes {
#   pitch: -15
#   velocity: 157
#   start_time: -0.7990103363990784
#   end_time: -0.2198956161737442
#   instrument: -73
#   program: -12
# }
# notes {
#   pitch: 30
#   velocity: -65
#   start_time: 1.2329195737838745
#   end_time: 0.6156952381134033
#   instrument: 9
#   program: 100
# }
# notes {
#   pitch: 42
#   velocity: 207
#   start_time: 0.6984251141548157
#   end_time: 0.32068687677383423
#   instrument: 137
#   program: -94
# }
# notes {
#   pitch: 121
#   velocity: -96
#   start_time: 0.5352993011474609
#   end_time: 0.1761246919631958
#   instrument: 176
#   program: 125
# }
# notes {
#   pitch: 146
#   velocity: 57
#   start_time: -0.22886759042739868
#   end_time: 0.10972467809915543
#   instrument: 140
#   program: 173
# }
# notes {
#   pitch: 189
#   velocity: 78
#   start_time: 0.5131144523620605
#   end_time: 1.2725045680999756
#   instrument: 111
#   program: -170
# }
# notes {
#   pitch: 22
#   velocity: -3
#   start_time: -0.48361876606941223
#   end_time: -0.42688536643981934
#   instrument: 148
#   program: -18
# }
# notes {
#   pitch: 109
#   velocity: -81
#   start_time: 1.1746084690093994
#   end_time: -0.6652814745903015
#   instrument: 154
#   program: 140
# }
# notes {
#   pitch: 194
#   velocity: 13
#   start_time: 1.707005500793457
#   end_time: 0.027907848358154297
#   instrument: 63
#   program: 193
# }
# notes {
#   pitch: 42
#   velocity: 8
#   start_time: 0.8588319420814514
#   end_time: 0.5209418535232544
#   instrument: 145
# }
# notes {
#   pitch: 111
#   velocity: -106
#   start_time: -0.5827472805976868
#   end_time: 1.7451286315917969
#   instrument: 220
#   program: -21
# }
# notes {
#   pitch: 142
#   velocity: -44
#   start_time: -0.18751049041748047
#   end_time: 0.8486419320106506
#   instrument: -117
#   program: 264
# }
# notes {
#   pitch: 152
#   velocity: 53
#   start_time: 1.3041306734085083
#   end_time: 0.4252391457557678
#   instrument: 114
#   program: 63
# }
# notes {
#   pitch: 16
#   velocity: 7
#   start_time: 0.8817108273506165
#   end_time: 1.7677109241485596
#   instrument: 7
#   program: 150
# }
# notes {
#   pitch: 134
#   velocity: 78
#   start_time: -0.045198798179626465
#   end_time: -0.5270040035247803
#   instrument: 125
#   program: 72
# }
# notes {
#   pitch: 187
#   velocity: 201
#   start_time: 1.1882100105285645
#   end_time: 1.3195624351501465
#   instrument: 98
#   program: 244
# }
# notes {
#   pitch: -41
#   velocity: 202
#   start_time: 1.459226369857788
#   end_time: 0.9299191236495972
#   instrument: -6
#   program: -89
# }
# notes {
#   pitch: 3
#   velocity: -85
#   start_time: -0.1375807672739029
#   end_time: 0.246596097946167
#   instrument: 221
#   program: 26
# }
# notes {
#   pitch: 157
#   velocity: -4
#   start_time: 0.4544631242752075
#   end_time: -0.975584089756012
#   instrument: 12
#   program: 153
# }
# notes {
#   pitch: 127
#   velocity: 117
#   start_time: 1.9385713338851929
#   end_time: 1.6719794273376465
#   instrument: -32
#   program: 100
# }
# notes {
#   pitch: -35
#   velocity: 113
#   start_time: -0.16314683854579926
#   end_time: 1.109808087348938
#   instrument: 85
#   program: -29
# }
# notes {
#   pitch: 116
#   velocity: -28
#   start_time: -0.13250058889389038
#   end_time: -0.2689279019832611
#   instrument: 62
#   program: 7
# }
# notes {
#   pitch: 65
#   velocity: 126
#   start_time: 1.2097907066345215
#   end_time: 0.6161133050918579
#   instrument: -43
#   program: 132
# }
# notes {
#   pitch: -74
#   velocity: 143
#   start_time: 0.4322381913661957
#   end_time: -0.15759128332138062
#   instrument: 117
#   program: -43
# }
# notes {
#   pitch: 146
#   velocity: 69
#   start_time: -1.041271448135376
#   end_time: 0.12735366821289062
#   instrument: 69
#   program: -64
# }
# notes {
#   pitch: 141
#   velocity: 145
#   start_time: 0.9877426624298096
#   end_time: 0.2310521900653839
#   instrument: 96
#   program: 150
# }
# notes {
#   pitch: 150
#   velocity: -40
#   start_time: 0.8076744079589844
#   end_time: -0.2895663380622864
#   instrument: 96
#   program: -28
# }
# notes {
#   pitch: -25
#   velocity: -44
#   start_time: -0.6612578630447388
#   end_time: -0.43491584062576294
#   instrument: 81
#   program: 131
# }
# notes {
#   pitch: -22
#   velocity: 143
#   start_time: -0.401817262172699
#   end_time: 0.7500101327896118
#   instrument: 52
#   program: 178
# }
# notes {
#   pitch: 208
#   start_time: 0.8061177134513855
#   end_time: 0.8273268938064575
#   instrument: 38
#   program: 154
# }
# notes {
#   pitch: 77
#   velocity: 233
#   start_time: 1.3701117038726807
#   end_time: 1.3272676467895508
#   instrument: 10
#   program: -48
# }
# notes {
#   pitch: 110
#   velocity: 11
#   start_time: 0.45077019929885864
#   end_time: 0.28797024488449097
#   instrument: 273
#   program: 39
# }
# notes {
#   pitch: 168
#   velocity: 80
#   start_time: -0.09181171655654907
#   end_time: 0.23337681591510773
#   instrument: 20
#   program: 24
# }
# notes {
#   pitch: 156
#   velocity: 51
#   start_time: 0.47883278131484985
#   end_time: -0.23925364017486572
#   instrument: 134
#   program: 158
# }
# notes {
#   pitch: 49
#   velocity: 96
#   start_time: 0.6806347966194153
#   end_time: 1.1543045043945312
#   instrument: 6
#   program: 104
# }
# notes {
#   pitch: 116
#   velocity: -187
#   start_time: 0.8924466371536255
#   end_time: -0.14793725311756134
#   instrument: 175
#   program: -77
# }
# notes {
#   pitch: 212
#   velocity: 147
#   start_time: -0.07018548250198364
#   end_time: 0.09878844022750854
#   instrument: 92
#   program: -16
# }
# notes {
#   pitch: 55
#   velocity: 128
#   start_time: 0.20912492275238037
#   end_time: 1.0448708534240723
#   instrument: 20
#   program: -59
# }
# notes {
#   pitch: -42
#   velocity: -87
#   start_time: -0.3473309874534607
#   end_time: 0.9313941597938538
#   instrument: 190
#   program: 147
# }
# notes {
#   pitch: 177
#   velocity: -7
#   start_time: 0.9081722497940063
#   end_time: 0.7892389297485352
#   program: 18
# }
# notes {
#   pitch: 44
#   velocity: 36
#   start_time: 1.7800588607788086
#   end_time: 1.2402451038360596
#   instrument: 77
#   program: -59
# }
# notes {
#   pitch: 83
#   velocity: -45
#   start_time: 0.6542407870292664
#   end_time: 1.1125099658966064
#   instrument: 12
#   program: 93
# }
# notes {
#   pitch: -20
#   velocity: 83
#   start_time: -0.5835537910461426
#   end_time: -0.7556029558181763
#   instrument: -22
#   program: -22
# }
# notes {
#   pitch: 90
#   velocity: 92
#   start_time: 1.4202854633331299
#   end_time: -0.4576205015182495
#   instrument: -43
#   program: 182
# }
# notes {
#   pitch: 69
#   velocity: 225
#   start_time: 1.404039978981018
#   end_time: 0.12735378742218018
#   instrument: 168
#   program: -144
# }
# notes {
#   pitch: -8
#   velocity: -120
#   start_time: 0.5550830364227295
#   end_time: 0.8846451044082642
#   instrument: 165
#   program: 162
# }
# notes {
#   pitch: 151
#   velocity: 163
#   start_time: 0.6257632970809937
#   end_time: -0.2174619734287262
#   instrument: 96
#   program: 38
# }
# notes {
#   pitch: 186
#   velocity: 35
#   start_time: 1.2053320407867432
#   end_time: 1.3621346950531006
#   instrument: -50
#   program: 109
# }
# notes {
#   pitch: -3
#   velocity: 21
#   start_time: 0.5662581324577332
#   end_time: 0.49553877115249634
#   instrument: 123
#   program: -38
# }
# notes {
#   pitch: 135
#   velocity: 131
#   start_time: -0.3407740890979767
#   end_time: -0.4257218837738037
#   instrument: 121
#   program: 16
# }
# notes {
#   pitch: 241
#   velocity: 134
#   start_time: 1.0858778953552246
#   end_time: -0.3336438834667206
#   instrument: -62
#   program: 57
# }
# notes {
#   pitch: -132
#   velocity: 170
#   start_time: 1.0021941661834717
#   end_time: 1.2537546157836914
#   instrument: 44
#   program: -54
# }
# notes {
#   pitch: 132
#   velocity: 13
#   start_time: 0.12796801328659058
#   end_time: 1.0723135471343994
#   instrument: 251
#   program: 196
# }
# notes {
#   pitch: 78
#   velocity: 166
#   start_time: 1.3375296592712402
#   end_time: 0.12271323800086975
#   instrument: 26
#   program: 208
# }
# notes {
#   pitch: 43
#   velocity: 67
#   start_time: -0.21088141202926636
#   end_time: 0.29181134700775146
#   instrument: -8
#   program: 64
# }
# notes {
#   pitch: 18
#   velocity: 35
#   start_time: -0.2590150535106659
#   end_time: 0.45975378155708313
#   instrument: -10
#   program: 77
# }
# notes {
#   pitch: -12
#   velocity: -89
#   start_time: 1.1817532777786255
#   end_time: -0.006006509065628052
#   instrument: 119
#   program: 49
# }
# notes {
#   pitch: 40
#   velocity: 146
#   start_time: 1.7042733430862427
#   end_time: 0.9347692131996155
#   instrument: 61
#   program: -3
# }
# notes {
#   pitch: 148
#   velocity: 216
#   start_time: -0.059856116771698
#   end_time: 0.9764710068702698
#   instrument: 10
#   program: -11
# }
# notes {
#   pitch: -56
#   velocity: -91
#   start_time: 0.7865106463432312
#   end_time: -0.47347480058670044
#   instrument: 20
#   program: 149
# }
# notes {
#   pitch: -47
#   velocity: 125
#   start_time: 1.5065646171569824
#   end_time: 0.6349076628684998
#   instrument: -155
#   program: 85
# }
# notes {
#   pitch: 29
#   velocity: 88
#   start_time: 0.46397918462753296
#   end_time: 0.07393711805343628
#   instrument: 21
#   program: -102
# }
# notes {
#   pitch: -50
#   velocity: -45
#   start_time: 0.398199200630188
#   end_time: 1.066953182220459
#   instrument: 173
#   program: -74
# }
# notes {
#   pitch: 233
#   velocity: -55
#   start_time: 0.9724189043045044
#   end_time: -0.3916943073272705
#   instrument: 40
#   program: 135
# }
# notes {
#   pitch: -61
#   velocity: 188
#   start_time: 1.5104659795761108
#   end_time: 0.5123366117477417
#   instrument: 98
#   program: 136
# }
# notes {
#   pitch: 68
#   velocity: 116
#   start_time: 1.2461585998535156
#   end_time: 1.2938427925109863
#   instrument: 66
#   program: -29
# }
# notes {
#   pitch: 126
#   velocity: -2
#   start_time: -0.6020900011062622
#   end_time: 2.043630599975586
#   instrument: 82
#   program: 18
# }
# notes {
#   pitch: 23
#   velocity: -29
#   start_time: 0.04488837718963623
#   end_time: 0.4811750054359436
#   instrument: 121
#   program: 201
# }
# notes {
#   pitch: 24
#   velocity: 3
#   start_time: 1.9671363830566406
#   end_time: 0.16133922338485718
#   instrument: 161
#   program: 63
# }
# notes {
#   pitch: 77
#   velocity: 24
#   start_time: -0.14604808390140533
#   end_time: 0.5384851098060608
#   instrument: -60
#   program: 179
# }
# notes {
#   pitch: 180
#   velocity: 73
#   start_time: -0.33374980092048645
#   end_time: 0.47681379318237305
#   instrument: 137
#   program: 88
# }
# notes {
#   pitch: 152
#   velocity: -52
#   start_time: 1.3057239055633545
#   end_time: 0.9322241544723511
#   instrument: -51
#   program: 167
# }
# notes {
#   pitch: -69
#   velocity: 200
#   start_time: 0.666874885559082
#   end_time: 1.3039536476135254
#   instrument: 57
#   program: 22
# }
# notes {
#   pitch: -97
#   velocity: 143
#   start_time: -0.3599923849105835
#   end_time: 0.06844320893287659
#   instrument: -22
#   program: 120
# }
# notes {
#   pitch: 14
#   velocity: 86
#   start_time: 1.416286826133728
#   end_time: 0.06637261807918549
#   instrument: -122
#   program: 76
# }
# notes {
#   pitch: 30
#   velocity: 71
#   start_time: 1.1491217613220215
#   end_time: 0.06542348861694336
#   instrument: -42
#   program: -80
# }
# notes {
#   pitch: 58
#   velocity: 16
#   start_time: -0.43035176396369934
#   end_time: 1.3862807750701904
#   instrument: 119
#   program: 82
# }
# notes {
#   pitch: 42
#   velocity: 88
#   start_time: 0.11824032664299011
#   end_time: 0.027642101049423218
#   instrument: 181
#   program: 152
# }
# notes {
#   pitch: 175
#   velocity: 138
#   start_time: 0.0004291534423828125
#   end_time: -0.2578127384185791
#   instrument: 57
#   program: 120
# }
# notes {
#   pitch: -99
#   velocity: 160
#   start_time: 1.3056615591049194
#   end_time: 1.8252350091934204
#   instrument: 129
#   program: -107
# }
# notes {
#   pitch: -71
#   velocity: -127
#   start_time: -0.6380854845046997
#   end_time: 0.42267870903015137
#   instrument: 162
#   program: 76
# }
# notes {
#   pitch: 45
#   velocity: 68
#   start_time: 1.1902735233306885
#   end_time: -0.987021803855896
#   instrument: 24
#   program: 266
# }
# notes {
#   pitch: 12
#   velocity: 64
#   start_time: 0.556197464466095
#   end_time: 1.4774754047393799
#   instrument: 100
#   program: -52
# }
# notes {
#   pitch: 46
#   velocity: 33
#   start_time: 0.20455631613731384
#   end_time: 1.1559102535247803
#   instrument: -13
#   program: 143
# }
# notes {
#   pitch: 102
#   velocity: 35
#   start_time: 0.013253390789031982
#   end_time: 0.6040399074554443
#   instrument: 180
#   program: -50
# }
# notes {
#   pitch: -28
#   velocity: -29
#   start_time: -0.3739110231399536
#   end_time: 0.929018497467041
#   instrument: -8
#   program: -8
# }
# notes {
#   pitch: -104
#   velocity: 92
#   start_time: 0.9733358025550842
#   end_time: -0.4595832824707031
#   instrument: 235
#   program: -17
# }
# notes {
#   pitch: 97
#   velocity: -47
#   start_time: 0.9780059456825256
#   end_time: 0.030189037322998047
#   instrument: 242
#   program: 27
# }
# notes {
#   pitch: 6
#   velocity: -60
#   start_time: 0.49696528911590576
#   end_time: -1.1068617105484009
#   instrument: -88
#   program: 135
# }
# notes {
#   pitch: 15
#   velocity: 134
#   start_time: 1.1062031984329224
#   end_time: 0.2717892527580261
#   instrument: 41
#   program: 179
# }
# notes {
#   pitch: 112
#   velocity: 78
#   start_time: -0.8114065527915955
#   end_time: 1.9397627115249634
#   instrument: 190
#   program: 129
# }
# notes {
#   pitch: 114
#   velocity: -31
#   start_time: 0.027964532375335693
#   end_time: -0.3510921895503998
#   instrument: 155
#   program: 50
# }
# notes {
#   pitch: 155
#   velocity: 173
#   start_time: 1.4588210582733154
#   end_time: 1.2632100582122803
#   instrument: -80
#   program: 153
# }
# notes {
#   pitch: 13
#   velocity: 234
#   start_time: 0.6214463710784912
#   end_time: -0.2136526107788086
#   instrument: 30
#   program: -30
# }
# notes {
#   pitch: 130
#   velocity: -87
#   start_time: 0.6522018909454346
#   end_time: 0.7152137160301208
#   instrument: 208
#   program: 2
# }
# notes {
#   pitch: -1
#   velocity: 109
#   start_time: 0.680599570274353
#   end_time: -0.5850111246109009
#   instrument: 121
#   program: 260
# }
# notes {
#   pitch: -13
#   velocity: 62
#   start_time: -0.030907392501831055
#   end_time: 1.1935007572174072
#   instrument: -42
#   program: -110
# }
# notes {
#   pitch: -37
#   velocity: 57
#   start_time: -1.0011661052703857
#   end_time: 1.39870285987854
#   instrument: 184
#   program: -96
# }
# notes {
#   pitch: 224
#   velocity: -55
#   start_time: 0.32604822516441345
#   end_time: 1.0143929719924927
#   instrument: 18
#   program: 90
# }
# notes {
#   pitch: 44
#   velocity: -35
#   start_time: 1.6629825830459595
#   end_time: 0.03311796486377716
#   instrument: 72
#   program: 153
# }
# notes {
#   pitch: 118
#   velocity: 219
#   start_time: 1.4794533252716064
#   end_time: 0.3957902193069458
#   instrument: 247
#   program: 31
# }
# notes {
#   pitch: -53
#   velocity: 41
#   start_time: -0.43582385778427124
#   end_time: 1.3060635328292847
#   instrument: 67
#   program: 34
# }
# notes {
#   velocity: 115
#   start_time: 0.08840501308441162
#   end_time: -1.0447533130645752
#   instrument: -11
#   program: 204
# }
# notes {
#   pitch: 21
#   velocity: 65
#   start_time: 1.4866316318511963
#   end_time: 1.1259981393814087
#   instrument: -50
#   program: 34
# }
# notes {
#   pitch: 109
#   velocity: 61
#   start_time: -0.4858854413032532
#   end_time: 0.883563756942749
#   instrument: -65
#   program: 103
# }
# notes {
#   pitch: -10
#   velocity: -30
#   start_time: 1.1543114185333252
#   end_time: -0.2623826563358307
#   instrument: 98
#   program: 66
# }
# notes {
#   pitch: -1
#   velocity: 206
#   start_time: 0.19589364528656006
#   end_time: -0.40468358993530273
#   instrument: 55
#   program: 195
# }
# notes {
#   pitch: 87
#   velocity: 227
#   start_time: -0.42138051986694336
#   end_time: 1.6959340572357178
#   instrument: -62
#   program: -98
# }
# notes {
#   pitch: 16
#   velocity: 71
#   start_time: 0.7874797582626343
#   end_time: 0.19918453693389893
#   instrument: 51
#   program: 142
# }
# notes {
#   pitch: 10
#   velocity: 218
#   start_time: 1.5782115459442139
#   end_time: -0.47789984941482544
#   instrument: 4
#   program: 66
# }
# notes {
#   pitch: 49
#   velocity: 148
#   start_time: 1.106910228729248
#   end_time: 1.882033348083496
#   instrument: -50
#   program: -41
# }
# notes {
#   pitch: -144
#   velocity: 126
#   start_time: -0.6853353381156921
#   end_time: 0.5907560586929321
#   program: 3
# }
# notes {
#   pitch: 178
#   velocity: 12
#   start_time: -0.7522532939910889
#   end_time: 0.10283640027046204
#   instrument: 104
#   program: 156
# }
# notes {
#   pitch: 124
#   velocity: 126
#   start_time: 0.46712201833724976
#   end_time: 0.11955738067626953
#   instrument: 11
#   program: -1
# }
# notes {
#   pitch: -23
#   velocity: 100
#   start_time: 0.528754472732544
#   end_time: 1.7244462966918945
#   instrument: 130
#   program: 117
# }
# notes {
#   pitch: 125
#   velocity: 86
#   start_time: 0.5522102117538452
#   end_time: 1.241241455078125
#   instrument: 190
#   program: 117
# }
# notes {
#   pitch: 38
#   velocity: 157
#   start_time: 1.1013754606246948
#   end_time: -0.8811511993408203
#   instrument: 39
#   program: 168
# }
# notes {
#   pitch: 5
#   velocity: -96
#   start_time: 0.5541843771934509
#   end_time: 1.4977521896362305
#   instrument: 128
#   program: 55
# }
# notes {
#   pitch: 39
#   velocity: 78
#   start_time: 1.0721650123596191
#   end_time: 2.078725576400757
#   instrument: 73
#   program: -70
# }
# notes {
#   pitch: 121
#   velocity: -15
#   start_time: 0.7791084051132202
#   end_time: 0.5997995138168335
#   instrument: -22
#   program: 158
# }
# notes {
#   pitch: 84
#   velocity: 28
#   start_time: 1.2954975366592407
#   end_time: 0.1943318247795105
#   instrument: -65
#   program: 33
# }
# notes {
#   pitch: -128
#   velocity: 112
#   start_time: 1.8522446155548096
#   end_time: 1.3812787532806396
#   instrument: 155
#   program: -129
# }
# notes {
#   pitch: 2
#   velocity: -72
#   start_time: 0.15556856989860535
#   end_time: 0.3546183109283447
#   instrument: 236
#   program: -2
# }
# notes {
#   pitch: 21
#   velocity: -37
#   start_time: 1.3348982334136963
#   end_time: 0.8755303621292114
#   instrument: -93
#   program: 165
# }
# notes {
#   velocity: 109
#   start_time: 0.8527178764343262
#   end_time: 0.22204387187957764
#   instrument: 62
#   program: -25
# }
# notes {
#   pitch: 35
#   velocity: 131
#   start_time: 0.06162788346409798
#   end_time: 0.8262190818786621
#   instrument: 135
#   program: -60
# }
# notes {
#   pitch: 153
#   velocity: -27
#   start_time: -0.419772207736969
#   end_time: -0.3601950407028198
#   instrument: 25
#   program: 179
# }
# notes {
#   pitch: 51
#   velocity: 145
#   start_time: 0.578727662563324
#   end_time: -0.5525076389312744
#   instrument: -102
#   program: 177
# }
# notes {
#   pitch: -91
#   velocity: 183
#   start_time: 1.0095365047454834
#   end_time: -0.07564049959182739
#   instrument: 131
#   program: 29
# }
# notes {
#   pitch: 137
#   velocity: 154
#   start_time: 1.151505470275879
#   end_time: 1.3803497552871704
#   instrument: 9
#   program: 183
# }
# notes {
#   pitch: 83
#   velocity: 107
#   start_time: 0.025307655334472656
#   end_time: -1.2106826305389404
#   instrument: 57
#   program: 130
# }
# notes {
#   pitch: 35
#   velocity: 174
#   start_time: 1.1424610614776611
#   end_time: 1.0509493350982666
#   instrument: 115
#   program: 30
# }
# notes {
#   pitch: -132
#   velocity: 145
#   start_time: -0.7845872044563293
#   end_time: 1.3489232063293457
#   instrument: 182
#   program: 125
# }
# notes {
#   pitch: 49
#   start_time: -0.47078531980514526
#   end_time: -0.46510815620422363
#   instrument: 21
#   program: 7
# }
# notes {
#   pitch: 206
#   velocity: 130
#   start_time: 1.2172290086746216
#   end_time: 0.9576983451843262
#   instrument: 81
#   program: 43
# }
# notes {
#   pitch: 108
#   velocity: 157
#   start_time: 1.0579078197479248
#   end_time: 0.7040084004402161
#   instrument: 21
#   program: 33
# }
# notes {
#   pitch: 27
#   velocity: -34
#   start_time: 0.503558337688446
#   end_time: 1.9323605298995972
#   instrument: 203
#   program: 152
# }
# notes {
#   pitch: 38
#   velocity: 108
#   start_time: 1.6749476194381714
#   end_time: 0.13570824265480042
#   instrument: -113
#   program: 75
# }
# notes {
#   pitch: 39
#   velocity: -29
#   start_time: 1.674560308456421
#   end_time: 0.12048137187957764
#   instrument: 124
#   program: -155
# }
# notes {
#   pitch: -142
#   velocity: 131
#   start_time: 0.2817240357398987
#   end_time: 1.678321361541748
#   instrument: -97
#   program: -54
# }
# notes {
#   pitch: -99
#   velocity: 68
#   start_time: -0.2651898264884949
#   end_time: 0.12608838081359863
#   instrument: 165
#   program: 147
# }
# notes {
#   pitch: 117
#   velocity: 230
#   start_time: 0.9315179586410522
#   end_time: 0.9399237632751465
#   program: 146
# }
# notes {
#   pitch: 86
#   velocity: 23
#   start_time: 1.5284440517425537
#   end_time: 0.6677517294883728
#   instrument: 72
#   program: 1
# }
# notes {
#   pitch: -39
#   velocity: -122
#   start_time: 0.4677045941352844
#   end_time: 0.9446364641189575
#   instrument: 214
#   program: -22
# }
# notes {
#   pitch: 61
#   velocity: 173
#   start_time: -0.1612023115158081
#   end_time: 0.7861340045928955
#   instrument: -15
#   program: 184
# }
# notes {
#   pitch: -50
#   velocity: -32
#   start_time: 1.9123601913452148
#   end_time: -0.16165971755981445
#   instrument: -64
#   program: 57
# }
# notes {
#   pitch: -122
#   velocity: -46
#   start_time: -1.0170191526412964
#   end_time: 1.4542577266693115
#   instrument: 214
#   program: -61
# }
# notes {
#   pitch: 162
#   velocity: 22
#   start_time: 0.5545570850372314
#   end_time: -0.7779451608657837
#   instrument: 217
#   program: 9
# }
# notes {
#   pitch: 164
#   velocity: 81
#   start_time: 0.2452923059463501
#   end_time: -0.34366893768310547
#   instrument: 77
#   program: 138
# }
# notes {
#   pitch: 24
#   velocity: 48
#   start_time: 1.3933309316635132
#   end_time: 1.5573819875717163
#   instrument: 192
#   program: 102
# }
# notes {
#   pitch: 120
#   velocity: -11
#   start_time: -0.5167574882507324
#   end_time: 1.5774935483932495
#   instrument: 184
#   program: 155
# }
# notes {
#   pitch: 18
#   velocity: -63
#   start_time: 0.33543333411216736
#   end_time: 0.2901190519332886
#   instrument: 42
#   program: 78
# }
# notes {
#   pitch: 53
#   velocity: 110
#   start_time: 0.5055020451545715
#   end_time: 0.9518085718154907
#   instrument: 6
#   program: 126
# }
# notes {
#   pitch: 41
#   velocity: 135
#   start_time: -0.21112364530563354
#   end_time: 1.7308366298675537
#   instrument: 143
#   program: 82
# }
# notes {
#   pitch: 56
#   velocity: 73
#   start_time: 0.45315662026405334
#   end_time: 0.6542619466781616
#   instrument: 24
#   program: -6
# }
# notes {
#   pitch: 225
#   velocity: 14
#   start_time: 1.4004247188568115
#   end_time: 1.522486925125122
#   instrument: -91
# }
# notes {
#   pitch: -45
#   velocity: 103
#   start_time: 0.14530009031295776
#   end_time: 0.4549826383590698
#   instrument: 61
#   program: -4
# }
# notes {
#   pitch: -19
#   velocity: -94
#   start_time: -0.7347772121429443
#   end_time: 1.4493926763534546
#   instrument: 158
#   program: -7
# }
# notes {
#   pitch: -83
#   velocity: 59
#   start_time: 0.8784728050231934
#   end_time: -0.5908392667770386
#   instrument: -88
#   program: 159
# }
# notes {
#   pitch: 96
#   velocity: -105
#   start_time: 1.7765898704528809
#   end_time: 0.8925413489341736
#   instrument: 116
#   program: -80
# }
# notes {
#   pitch: 105
#   velocity: 53
#   start_time: -0.7038720846176147
#   end_time: 1.4208178520202637
#   instrument: 144
#   program: 74
# }
# notes {
#   pitch: 118
#   velocity: -79
#   start_time: 0.1951795518398285
#   end_time: -0.8376062512397766
#   instrument: -2
#   program: -16
# }
# notes {
#   pitch: 259
#   velocity: 144
#   start_time: 0.9533610939979553
#   end_time: -0.10805749893188477
#   instrument: 43
#   program: 171
# }
# notes {
#   pitch: 20
#   velocity: -22
#   start_time: 0.5310930609703064
#   end_time: 0.6607697010040283
#   instrument: 157
#   program: -72
# }
# notes {
#   pitch: -53
#   velocity: 28
#   start_time: 0.45457178354263306
#   end_time: 0.8179814219474792
#   instrument: 163
#   program: 22
# }
# notes {
#   pitch: -44
#   velocity: 159
#   start_time: 0.12195861339569092
#   end_time: -0.5678325295448303
#   instrument: 17
#   program: 150
# }
# notes {
#   pitch: 36
#   velocity: 122
#   start_time: 1.5607109069824219
#   end_time: 0.6521639823913574
#   instrument: 142
#   program: 39
# }
# notes {
#   pitch: 70
#   velocity: 112
#   start_time: 0.2323685586452484
#   end_time: 1.5826343297958374
#   instrument: 209
#   program: -22
# }
# notes {
#   pitch: -51
#   velocity: -88
#   start_time: 0.8620529174804688
#   end_time: -1.369978904724121
#   instrument: 125
#   program: 168
# }
# notes {
#   pitch: 235
#   velocity: 49
#   start_time: 0.9347254037857056
#   end_time: 0.947984516620636
#   instrument: 19
#   program: 129
# }
# notes {
#   pitch: -74
#   velocity: 190
#   start_time: 0.04498910903930664
#   end_time: 0.5267238616943359
#   instrument: 175
#   program: 6
# }
# notes {
#   pitch: 2
#   velocity: -66
#   start_time: 0.10162979364395142
#   end_time: 0.18643200397491455
#   instrument: 213
# }
# notes {
#   pitch: 47
#   velocity: 125
#   start_time: 1.3359923362731934
#   end_time: -0.25438928604125977
#   instrument: 107
#   program: 232
# }
# notes {
#   pitch: 47
#   velocity: 72
#   start_time: 1.638777256011963
#   end_time: 0.8784881830215454
#   instrument: 123
#   program: 80
# }
# notes {
#   pitch: 7
#   velocity: 172
#   start_time: -0.806826114654541
#   end_time: 1.766167402267456
#   instrument: 231
#   program: 115
# }
# notes {
#   pitch: 80
#   velocity: 141
#   start_time: 0.23772385716438293
#   end_time: 0.14381013810634613
#   instrument: 28
#   program: 3
# }
# notes {
#   pitch: 277
#   velocity: 77
#   start_time: 1.5073254108428955
#   end_time: 0.7343060970306396
#   instrument: 120
#   program: 38
# }
# notes {
#   pitch: -100
#   velocity: 203
#   start_time: 1.1632335186004639
#   end_time: -0.0109025239944458
#   instrument: 37
#   program: -35
# }
# notes {
#   pitch: -52
#   velocity: 49
#   start_time: -0.03186492621898651
#   end_time: 1.1364669799804688
#   instrument: 85
#   program: 89
# }
# notes {
#   pitch: -23
#   velocity: 165
#   start_time: 1.1124602556228638
#   end_time: 0.5632337927818298
#   instrument: -18
#   program: 156
# }
# notes {
#   pitch: 13
#   velocity: 129
#   start_time: 0.5259941816329956
#   end_time: 0.9760528802871704
#   instrument: -38
#   program: 127
# }
# notes {
#   pitch: -26
#   velocity: -119
#   start_time: -0.3952774703502655
#   end_time: 1.3698844909667969
#   instrument: -23
#   program: 57
# }
# notes {
#   pitch: 21
#   velocity: -164
#   start_time: -0.21692559123039246
#   end_time: -0.3939034342765808
#   instrument: 83
#   program: 114
# }
# notes {
#   pitch: 157
#   velocity: 57
#   start_time: 1.3769218921661377
#   end_time: 0.6197196245193481
#   instrument: -154
#   program: 220
# }
# notes {
#   pitch: 69
#   velocity: 155
#   start_time: 1.4443259239196777
#   end_time: 1.1098442077636719
#   instrument: 168
#   program: 84
# }
# notes {
#   pitch: 79
#   velocity: 16
#   start_time: -0.9056015014648438
#   end_time: 0.04080510139465332
#   instrument: 243
#   program: 129
# }
# notes {
#   pitch: 5
#   velocity: 136
#   start_time: 1.6260415315628052
#   end_time: 1.2577093839645386
#   instrument: -44
#   program: 134
# }
# notes {
#   pitch: 11
#   velocity: 9
#   start_time: 1.528663158416748
#   end_time: 1.6439073085784912
#   instrument: 132
#   program: 30
# }
# notes {
#   pitch: 134
#   velocity: 149
#   start_time: -0.1791825294494629
#   end_time: 0.2157658040523529
#   instrument: 145
#   program: -26
# }
# notes {
#   pitch: 224
#   velocity: -11
#   start_time: -0.09811824560165405
#   end_time: -0.1136731505393982
#   instrument: 132
#   program: 8
# }
# notes {
#   pitch: 148
#   velocity: 214
#   start_time: 1.3281300067901611
#   end_time: 0.758401095867157
#   instrument: -162
#   program: 112
# }
# notes {
#   pitch: 93
#   velocity: 220
#   start_time: 0.012724101543426514
#   end_time: 0.27358680963516235
#   instrument: 99
#   program: -18
# }
# notes {
#   pitch: 147
#   velocity: -84
#   start_time: 0.9778517484664917
#   end_time: 1.287775993347168
#   instrument: 175
#   program: -69
# }
# notes {
#   pitch: 36
#   velocity: -44
#   start_time: 1.4482346773147583
#   end_time: 0.31931644678115845
#   instrument: -56
#   program: 47
# }
# notes {
#   velocity: 93
#   start_time: 1.574179768562317
#   end_time: 0.9347025156021118
#   instrument: 56
#   program: 99
# }

# %%
generated_midi_npy
# Out:
# array([[[ 0.5080292 , -0.7779212 ,  0.8818551 , ...,  0.19177091,
#          -0.8610696 ,  0.34808663],
#         [-0.39053985,  0.56780916, -0.8280029 , ...,  0.30370262,
#          -0.23198748,  0.5321382 ],
#         [-0.2616457 ,  0.90719813, -0.8010409 , ...,  1.2762916 ,
#          -0.18479165,  0.91178054],
#         ...,
#         [-0.2559999 , -1.1701323 ,  0.6741421 , ...,  0.98770565,
#           0.9670439 , -0.00183897],
#         [-0.75108516, -1.1975385 , -1.0212892 , ..., -1.208947  ,
#          -0.04282105,  0.9939269 ],
#         [ 0.840861  ,  0.40443105,  0.7856634 , ..., -1.1669009 ,
#          -1.1341034 , -0.4945601 ]]], dtype=float32)

# %%
np.max(generated_midi_npy)
# Out:
# 20.598913
